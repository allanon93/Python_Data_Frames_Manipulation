# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = df2.set_index("Address")

# %%
df2.iloc[1:4, 1:4]
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA
# 3995 23rd St    San Francisco          CA 94114     USA

# %%
df2.drop(df2.columns[2:5],1)
# Out:
# C:\Users\cyris\AppData\Local\Temp\ipykernel_14204\548962678.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df2.drop(df2.columns[2:5],1)
#                  ID           City  Employees
# Address
# 3666 21st St      1  San Francisco          8
# 735 Dolores St    2  San Francisco         15
# 332 Hill St       3  San Francisco         25
# 3995 23rd St      4  San Francisco         10
# 1056 Sanchez St   5  San Francisco         12
# 551 Alvarado St   6  San Francisco         20

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-commas.txt")
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.set_index("Address")
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
len(df5.index)
# Out:
# 6

# %%
df5["Continent"]=df5.shape[0]*["North America"]

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df5["Continent"]=df5["Country"]+ "," + "North America"

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees          Continent
# 0          8  USA,North America
# 1         15  USA,North America
# 2         25  USA,North America
# 3         10  USA,North America
# 4         12  USA,North America
# 5         20  USA,North America

# %%
df5_t=df5.T

# %%
df5_t
# Out:
#                            0                  1                  2  \
# ID                         1                  2                  3
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
#                            3                  4                  5
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# ...

# %%
df5_t[2]=["7","My Address","My City","My State","My Country","My Name","10","My Continent"]

# %%
df5 = df5_t.T

# %%
df5
# Out:
#   ID          Address           City       State     Country         Name  \
# 0  1     3666 21st St  San Francisco    CA 94114         USA      Madeira
# 1  2   735 Dolores St  San Francisco    CA 94119         USA  Bready Shop
# 2  7       My Address        My City    My State  My Country      My Name
# 3  4     3995 23rd St  San Francisco    CA 94114         USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco  California         USA      Sanchez
# 5  6  551 Alvarado St  San Francisco    CA 94114         USA   Richvalley
# 6  7       My Address        My City    My State  My Country      My Name
#
#   Employees          Continent
# 0         8  USA,North America
# 1        15  USA,North America
# 2        10       My Continent
# 3        10  USA,North America
# 4        12  USA,North America
# 5        20  USA,North America
# 6        10       My Continent

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
import pandas
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+ ", "+ df["City"]+ ", "+ df["State"]+ ", "+ df["Country"]

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, San Francisco, CA...  San Francisco
# 1   2  735 Dolores St, San Francisco, San Francisco, ...  San Francisco
# 2   3  332 Hill St, San Francisco, San Francisco, Cal...  San Francisco
# 3   4  3995 23rd St, San Francisco, San Francisco, CA...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, San Francisco,...  San Francisco
# 5   6  551 Alvarado St, San Francisco, San Francisco,...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df.drop(df.columns[2:5], 1)
# Out:
# C:\Users\cyris\AppData\Local\Temp\ipykernel_14204\1351707727.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns[2:5], 1)
#    ID                                            Address         Name  \
# 0   1  3666 21st St, San Francisco, San Francisco, CA...      Madeira
# 1   2  735 Dolores St, San Francisco, San Francisco, ...  Bready Shop
# 2   3  332 Hill St, San Francisco, San Francisco, Cal...  Super River
# 3   4  3995 23rd St, San Francisco, San Francisco, CA...   Ben's Shop
# 4   5  1056 Sanchez St, San Francisco, San Francisco,...      Sanchez
# 5   6  551 Alvarado St, San Francisco, San Francisco,...   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.set_index("ID")
# Out:
#                                               Address           City  \
# ID
# 1   3666 21st St, San Francisco, San Francisco, CA...  San Francisco
# 2   735 Dolores St, San Francisco, San Francisco, ...  San Francisco
# 3   332 Hill St, San Francisco, San Francisco, Cal...  San Francisco
# 4   3995 23rd St, San Francisco, San Francisco, CA...  San Francisco
# 5   1056 Sanchez St, San Francisco, San Francisco,...  San Francisco
# 6   551 Alvarado St, San Francisco, San Francisco,...  San Francisco
#
#                State Country         Name  Employees
# ID
# 1           CA 94114     USA      Madeira          8
# 2           CA 94119     USA  Bready Shop         15
# 3   California 94114     USA  Super River         25
# 4           CA 94114     USA   Ben's Shop         10
# 5         California     USA      Sanchez         12
# 6           CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, San Francisco, CA...  San Francisco
# 1   2  735 Dolores St, San Francisco, San Francisco, ...  San Francisco
# 2   3  332 Hill St, San Francisco, San Francisco, Cal...  San Francisco
# 3   4  3995 23rd St, San Francisco, San Francisco, CA...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, San Francisco,...  San Francisco
# 5   6  551 Alvarado St, San Francisco, San Francisco,...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756632001957215, -122.42941101194798, 0.0))

# %%
df.Coordinates[3].longitude
# Out:
# -122.43170295955227

# %%
df["Longitude"] = df["Coordinates"].apply(lambda y: y.longitude if y != None else None)
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, San Francisco, CA...  San Francisco
# 1   2  735 Dolores St, San Francisco, San Francisco, ...  San Francisco
# 2   3  332 Hill St, San Francisco, San Francisco, Cal...  San Francisco
# 3   4  3995 23rd St, San Francisco, San Francisco, CA...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, San Francisco,...  San Francisco
# 5   6  551 Alvarado St, San Francisco, San Francisco,...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Longitude   Latitude
# ...
